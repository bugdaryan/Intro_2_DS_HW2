# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
train_df = pd.read_csv('Regression data/train.csv')
test_df = pd.read_csv('Regression data/test.csv')
pos_test = test_df[test_df['Predicted'] > 0]
neg_test = test_df[test_df['Predicted'] < 0]

# %%
cat_feats = ['model', 'year', 'transmission', 'fuel type']
num_feats = ['mileage', 'engine size']

# %%
train_df
# Out:
#           model    year transmission  mileage fuel type  engine size    price
# 0            A3  2018.0       Manual  11396.0    Petrol          1.5  19100.0
# 1            A3  2017.0       Manual  11706.0    Petrol          1.5  16500.0
# 2       C Class  2019.0    Semi-Auto  15195.0    Diesel          2.0  25999.0
# 3         Focus  2017.0    Semi-Auto  26482.0    Diesel          1.5  12390.0
# 4         Focus  2017.0       Manual  15375.0    Petrol          1.0  11768.0
# ...         ...     ...          ...      ...       ...          ...      ...
# 13477        Q3  2016.0       Manual  22270.0    Petrol          1.4  15845.0
# 13478        A3  2016.0    Semi-Auto  12166.0    Petrol          1.4  17498.0
# 13479     Focus  2017.0       Manual  10000.0    Petrol          1.0  13990.0
# 13480   C Class  2016.0    Semi-Auto  14996.0    Diesel          2.1  18480.0
# 13481        A3  2016.0    Semi-Auto  27306.0    Diesel          2.0  15945.0
#
# [13482 rows x 7 columns]

# %%
for col in cat_feats:
    plt.figure(figsize=(15,5))
    plt.subplot(1,2,1)
    plt.title(col+': Negative values')
    test_df[col].value_counts().plot(kind='bar')
    plt.subplot(1,2,2)
    plt.title(col+': Positive values')
    train_df[col].value_counts().plot(kind='bar')

for col in num_feats:
    plt.figure(figsize=(15,5))
    plt.subplot(1,2,1)
    plt.title(col+': Negative values')
    test_df[col].plot.density()
    plt.subplot(1,2,2)
    plt.title(col+': Positive values')
    train_df[col].plot.density()

# %%
for col in cat_feats:
    plt.figure(figsize=(15,5))
    plt.subplot(1,2,1)
    plt.title(col+': Negative values')
    neg_train[col].value_counts().plot(kind='bar')
    plt.subplot(1,2,2)
    plt.title(col+': Positive values')
    pos_train[col].value_counts().plot(kind='bar')

for col in num_feats:
    plt.figure(figsize=(15,5))
    plt.subplot(1,2,1)
    plt.title(col+': Negative values')
    neg_train[col].plot.density()
    plt.subplot(1,2,2)
    plt.title(col+': Positive values')
    pos_train[col].plot.density()
